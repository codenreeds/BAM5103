# %%
import pandas as pd
# Out:
# Running cells with 'bam5103 (3.11.x) (Python 3.11.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Project/AIMBA/BAM5103/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print("hello")
# Out:
# Running cells with 'bam5103 (3.11.x) (Python 3.11.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Project/AIMBA/BAM5103/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Out:
# Running cells with 'bam5103 (3.11.x) (Python 3.11.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Project/AIMBA/BAM5103/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
